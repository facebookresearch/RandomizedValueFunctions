# %% [markdown]
# ## 1

# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt 
with open("output/Hopper-v4-run30/RS_train_log", 'r') as temp_f:
    # get No of columns in each line
    col_count = [ len(l.split(" ")) for l in temp_f.readlines() ]
### Generate column names  (names will be 0, 1, 2, ..., maximum columns - 1)
column_names = [i for i in range(0, max(col_count)+1)]

# %%
df_1 = pd.read_csv("output/Hopper-v4-run30/RS_train_log", header=None, sep=':', names=column_names)
df_1 = pd.Series(df_1[41:][5])
df_2 = pd.read_csv("output/Hopper-v4-run31/RS_train_log", header=None, sep=':', names=column_names)
df_2 = pd.Series(df_2[41:][5])
df_2
plt.plot(df_1, label='ddpg', alpha=0.7)
plt.plot(df_2, label='swag', alpha=0.7)
plt.legend()

# %%
df_1 = pd.read_csv("swag/cartpole/RS_train_log_plain.txt", header=None, sep='\s+', names=column_names)
df_1 = df_1[7:6500]
df_1[2] = df_1[2].astype(int)
df_1[4] = df_1[4].astype(float)
df_1[6] = df_1[6].astype(float)
df_1[8] = df_1[8].astype(float)
df_1[10] = df_1[10].astype(float)
#df_1.insert(0, "idx", range(0,len(df_1)), allow_duplicates=True)


df_2 = pd.read_csv("swag_new/swag_spread_shared_step_lr_55.txt", header=None, sep='\s+', names=column_names)
df_2 = df_2[7:6500]
df_2[2] = df_2[2].astype(int)
df_2[4] = df_2[4].astype(float)
df_2[6] = df_2[6].astype(float)
df_2[8] = df_2[8].astype(float)
df_2[10] = df_2[10].astype(float)
#df_2.insert(0, "idx", range(0,len(df_2)), allow_duplicates=True)


df_3 = pd.read_csv("swag_new/swag_spread_shared_step_lr_123.txt", header=None, sep='\s+', names=column_names)
df_3 = df_3[7:6500]
df_3[2] = df_3[2].astype(int)
df_3[4] = df_3[4].astype(float)
df_3[6] = df_3[6].astype(float)
df_3[8] = df_3[8].astype(float)
df_3[10] = df_3[10].astype(float)
#df_3.insert(0, "idx", range(0,len(df_3)), allow_duplicates=True)

df_4 = pd.read_csv("swag_new/swag_spread_shared_step_lr_654.txt", header=None, sep='\s+', names=column_names)
df_4 = df_4[7:6500]
df_4[2] = df_4[2].astype(int)
df_4[4] = df_4[4].astype(float)
df_4[6] = df_4[6].astype(float)
df_4[8] = df_4[8].astype(float)
df_4[10] = df_4[10].astype(float)
#df_2.insert(0, "idx", range(0,len(df_2)), allow_duplicates=True)


df_5 = pd.read_csv("swag_new/swag_spread_shared_step_lr_777.txt", header=None, sep='\s+', names=column_names)
df_5 = df_5[7:6500]
df_5[2] = df_5[2].astype(int)
df_5[4] = df_5[4].astype(float)
df_5[6] = df_5[6].astype(float)
df_5[8] = df_5[8].astype(float)
df_5[10] = df_5[10].astype(float)
#df_3.insert(0, "idx", range(0,len(df_3)), allow_duplicates=True)

# %%
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

sns.set()
df1 = pd.Series(df_1[6].astype(float))
df2 = pd.Series(df_2[6].astype(float))
df3 = pd.Series(df_3[6].astype(float))
df4 = pd.Series(df_4[6].astype(float))
df5 = pd.Series(df_5[6].astype(float))
mean_out = np.mean([df1,df2, df3, df4, df5], axis = 0)
std_out = np.std([df1, df2, df3, df4, df5], axis=0)

plt.show()
plt.plot(range(len(df1)), mean_out, 'b-', label='reward')
plt.fill_between(range(len(df1)), mean_out - std_out, mean_out + std_out, color='b', alpha=0.2)
plt.legend('r')
print(np.mean(mean_out[-30:]))

sns.set()
df1 = pd.Series(df_1[8].astype(float))
df2 = pd.Series(df_2[8].astype(float))
df3 = pd.Series(df_3[8].astype(float))
df4 = pd.Series(df_4[8].astype(float))
df5 = pd.Series(df_5[8].astype(float))
mean_out = np.mean([df1,df2, df3, df4, df5], axis = 0)
std_out = np.std([df1, df2, df3, df4, df5], axis=0)

plt.show()
plt.plot(range(len(df1)), mean_out, 'b-', label='closs')
plt.fill_between(range(len(df1)), mean_out - std_out, mean_out + std_out, color='b', alpha=0.2)
plt.legend()
print(np.mean(mean_out[-30:]))

sns.set()
df1 = pd.Series(df_1[10].astype(float))
df2 = pd.Series(df_2[10].astype(float))
df3 = pd.Series(df_3[10].astype(float))
df4 = pd.Series(df_4[10].astype(float))
df5 = pd.Series(df_5[10].astype(float))
mean_out = np.mean([df1,df2, df3, df4, df5], axis = 0)
std_out = np.std([df1, df2, df3, df4, df5], axis=0)

plt.show()
plt.plot(range(len(df1)), mean_out, 'b-', label='aloss')
plt.fill_between(range(len(df1)), mean_out - std_out, mean_out + std_out, color='b', alpha=0.2)
plt.legend()
print(np.mean(mean_out[-30:]))
# Out:
# -182.35746733333337
# 0.8755766666666666
# 13.272587999999997

# %% [markdown]
# ## 2

# %%
with open("swag_new/swag_spread_shared_step_lr5e-3_1.txt", 'r') as temp_f:
    # get No of columns in each line
    col_count = [ len(l.split(" ")) for l in temp_f.readlines() ]
### Generate column names  (names will be 0, 1, 2, ..., maximum columns - 1)
column_names = [i for i in range(0, max(col_count)+1)]

df_1 = pd.read_csv("swag_new/swag_spread_shared_step_lr5e-3_1.txt", header=None, sep='\s+', names=column_names)
df_1 = df_1[7:6500]
df_1[2] = df_1[2].astype(int)
df_1[4] = df_1[4].astype(float)
df_1[6] = df_1[6].astype(float)
df_1[8] = df_1[8].astype(float)
df_1[10] = df_1[10].astype(float)
#df_1.insert(0, "idx", range(0,len(df_1)), allow_duplicates=True)


df_2 = pd.read_csv("swag_new/swag_spread_shared_step_lr5e-3_55.txt", header=None, sep='\s+', names=column_names)
df_2 = df_2[7:6500]
df_2[2] = df_2[2].astype(int)
df_2[4] = df_2[4].astype(float)
df_2[6] = df_2[6].astype(float)
df_2[8] = df_2[8].astype(float)
df_2[10] = df_2[10].astype(float)
#df_2.insert(0, "idx", range(0,len(df_2)), allow_duplicates=True)


df_3 = pd.read_csv("swag_new/swag_spread_shared_step_lr5e-3_123.txt", header=None, sep='\s+', names=column_names)
df_3 = df_3[7:6500]
df_3[2] = df_3[2].astype(int)
df_3[4] = df_3[4].astype(float)
df_3[6] = df_3[6].astype(float)
df_3[8] = df_3[8].astype(float)
df_3[10] = df_3[10].astype(float)
#df_3.insert(0, "idx", range(0,len(df_3)), allow_duplicates=True)

df_4 = pd.read_csv("swag_new/swag_spread_shared_step_lr5e-3_654.txt", header=None, sep='\s+', names=column_names)
df_4 = df_4[7:6500]
df_4[2] = df_4[2].astype(int)
df_4[4] = df_4[4].astype(float)
df_4[6] = df_4[6].astype(float)
df_4[8] = df_4[8].astype(float)
df_4[10] = df_4[10].astype(float)
#df_2.insert(0, "idx", range(0,len(df_2)), allow_duplicates=True)


df_5 = pd.read_csv("swag_new/swag_spread_shared_step_lr5e-3_777.txt", header=None, sep='\s+', names=column_names)
df_5 = df_5[7:6500]
df_5[2] = df_5[2].astype(int)
df_5[4] = df_5[4].astype(float)
df_5[6] = df_5[6].astype(float)
df_5[8] = df_5[8].astype(float)
df_5[10] = df_5[10].astype(float)
#df_3.insert(0, "idx", range(0,len(df_3)), allow_duplicates=True)

# %%
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

sns.set()
df1 = pd.Series(df_1[6].astype(float))
df2 = pd.Series(df_2[6].astype(float))
df3 = pd.Series(df_3[6].astype(float))
df4 = pd.Series(df_4[6].astype(float))
df5 = pd.Series(df_5[6].astype(float))
mean_out = np.mean([df1,df2, df3, df4, df5], axis = 0)
std_out = np.std([df1, df2, df3, df4, df5], axis=0)

plt.show()
plt.plot(range(len(df1)), mean_out, 'b-', label='reward')
plt.fill_between(range(len(df1)), mean_out - std_out, mean_out + std_out, color='b', alpha=0.2)
plt.legend('r')
print(np.mean(mean_out[-30:]))

sns.set()
df1 = pd.Series(df_1[8].astype(float))
df2 = pd.Series(df_2[8].astype(float))
df3 = pd.Series(df_3[8].astype(float))
df4 = pd.Series(df_4[8].astype(float))
df5 = pd.Series(df_5[8].astype(float))
mean_out = np.mean([df1,df2, df3, df4, df5], axis = 0)
std_out = np.std([df1, df2, df3, df4, df5], axis=0)

plt.show()
plt.plot(range(len(df1)), mean_out, 'b-', label='closs')
plt.fill_between(range(len(df1)), mean_out - std_out, mean_out + std_out, color='b', alpha=0.2)
plt.legend()
print(np.mean(mean_out[-30:]))

sns.set()
df1 = pd.Series(df_1[10].astype(float))
df2 = pd.Series(df_2[10].astype(float))
df3 = pd.Series(df_3[10].astype(float))
df4 = pd.Series(df_4[10].astype(float))
df5 = pd.Series(df_5[10].astype(float))
mean_out = np.mean([df1,df2, df3, df4, df5], axis = 0)
std_out = np.std([df1, df2, df3, df4, df5], axis=0)

plt.show()
plt.plot(range(len(df1)), mean_out, 'b-', label='aloss')
plt.fill_between(range(len(df1)), mean_out - std_out, mean_out + std_out, color='b', alpha=0.2)
plt.legend()
print(np.mean(mean_out[-30:]))
# Out:
# -173.09833933333329
# 0.8559146666666666
# 15.887781333333333

# %% [markdown]
# ## 3

# %%
with open("swag_new/swag_tag_shared_step_lr_1.txt", 'r') as temp_f:
    # get No of columns in each line
    col_count = [ len(l.split(" ")) for l in temp_f.readlines() ]
### Generate column names  (names will be 0, 1, 2, ..., maximum columns - 1)
column_names = [i for i in range(0, max(col_count)+1)]

df_1 = pd.read_csv("swag_new/swag_tag_shared_step_lr_1.txt", header=None, sep='\s+', names=column_names)
df_1 = df_1[7:6500]
df_1[2] = df_1[2].astype(int)
df_1[4] = df_1[4].astype(float)
df_1[6] = df_1[6].astype(float)
df_1[8] = df_1[8].astype(float)
df_1[10] = df_1[10].astype(float)
#df_1.insert(0, "idx", range(0,len(df_1)), allow_duplicates=True)


df_2 = pd.read_csv("swag_new/swag_tag_shared_step_lr_55.txt", header=None, sep='\s+', names=column_names)
df_2 = df_2[7:6500]
df_2[2] = df_2[2].astype(int)
df_2[4] = df_2[4].astype(float)
df_2[6] = df_2[6].astype(float)
df_2[8] = df_2[8].astype(float)
df_2[10] = df_2[10].astype(float)
#df_2.insert(0, "idx", range(0,len(df_2)), allow_duplicates=True)


df_3 = pd.read_csv("swag_new/swag_tag_shared_step_lr_123.txt", header=None, sep='\s+', names=column_names)
df_3 = df_3[7:6500]
df_3[2] = df_3[2].astype(int)
df_3[4] = df_3[4].astype(float)
df_3[6] = df_3[6].astype(float)
df_3[8] = df_3[8].astype(float)
df_3[10] = df_3[10].astype(float)
#df_3.insert(0, "idx", range(0,len(df_3)), allow_duplicates=True)

df_4 = pd.read_csv("swag_new/swag_tag_shared_step_lr_654.txt", header=None, sep='\s+', names=column_names)
df_4 = df_4[7:6500]
df_4[2] = df_4[2].astype(int)
df_4[4] = df_4[4].astype(float)
df_4[6] = df_4[6].astype(float)
df_4[8] = df_4[8].astype(float)
df_4[10] = df_4[10].astype(float)
#df_2.insert(0, "idx", range(0,len(df_2)), allow_duplicates=True)


df_5 = pd.read_csv("swag_new/swag_tag_shared_step_lr_777.txt", header=None, sep='\s+', names=column_names)
df_5 = df_5[7:6500]
df_5[2] = df_5[2].astype(int)
df_5[4] = df_5[4].astype(float)
df_5[6] = df_5[6].astype(float)
df_5[8] = df_5[8].astype(float)
df_5[10] = df_5[10].astype(float)
#df_3.insert(0, "idx", range(0,len(df_3)), allow_duplicates=True)

# %%
sns.set()
df1 = pd.Series(df_1[6].astype(float))
df2 = pd.Series(df_2[6].astype(float))
df3 = pd.Series(df_3[6].astype(float))
df4 = pd.Series(df_4[6].astype(float))
df5 = pd.Series(df_5[6].astype(float))
mean_out = np.mean([df1,df2, df3, df4, df5], axis = 0)
std_out = np.std([df1, df2, df3, df4, df5], axis=0)

plt.show()
plt.plot(range(len(df1)), mean_out, 'b-', label='reward')
plt.fill_between(range(len(df1)), mean_out - std_out, mean_out + std_out, color='b', alpha=0.2)
plt.legend('r')
print(np.mean(mean_out[-30:]))

sns.set()
df1 = pd.Series(df_1[8].astype(float))
df2 = pd.Series(df_2[8].astype(float))
df3 = pd.Series(df_3[8].astype(float))
df4 = pd.Series(df_4[8].astype(float))
df5 = pd.Series(df_5[8].astype(float))
mean_out = np.mean([df1,df2, df3, df4, df5], axis = 0)
std_out = np.std([df1, df2, df3, df4, df5], axis=0)

plt.show()
plt.plot(range(len(df1)), mean_out, 'b-', label='closs')
plt.fill_between(range(len(df1)), mean_out - std_out, mean_out + std_out, color='b', alpha=0.2)
plt.legend()
print(np.mean(mean_out[-30:]))

sns.set()
df1 = pd.Series(df_1[10].astype(float))
df2 = pd.Series(df_2[10].astype(float))
df3 = pd.Series(df_3[10].astype(float))
df4 = pd.Series(df_4[10].astype(float))
df5 = pd.Series(df_5[10].astype(float))
mean_out = np.mean([df1,df2, df3, df4, df5], axis = 0)
std_out = np.std([df1, df2, df3, df4, df5], axis=0)

plt.show()
plt.plot(range(len(df1)), mean_out, 'b-', label='aloss')
plt.fill_between(range(len(df1)), mean_out - std_out, mean_out + std_out, color='b', alpha=0.2)
plt.legend()
print(np.mean(mean_out[-30:]))
# Out:
# 12.133333333333333
# 1.0996593333333335
# 4.0257320000000005

# %% [markdown]
# ## 4

# %%
with open("swag_new/swag_tag_shared_step_lr_5e-3_1.txt", 'r') as temp_f:
    # get No of columns in each line
    col_count = [ len(l.split(" ")) for l in temp_f.readlines() ]
### Generate column names  (names will be 0, 1, 2, ..., maximum columns - 1)
column_names = [i for i in range(0, max(col_count)+1)]

df_1 = pd.read_csv("swag_new/swag_tag_shared_step_lr_5e-3_1.txt", header=None, sep='\s+', names=column_names)
df_1 = df_1[7:6500]
df_1[2] = df_1[2].astype(int)
df_1[4] = df_1[4].astype(float)
df_1[6] = df_1[6].astype(float)
df_1[8] = df_1[8].astype(float)
df_1[10] = df_1[10].astype(float)
#df_1.insert(0, "idx", range(0,len(df_1)), allow_duplicates=True)


df_2 = pd.read_csv("swag_new/swag_tag_shared_step_lr_5e-3_55.txt", header=None, sep='\s+', names=column_names)
df_2 = df_2[7:6500]
df_2[2] = df_2[2].astype(int)
df_2[4] = df_2[4].astype(float)
df_2[6] = df_2[6].astype(float)
df_2[8] = df_2[8].astype(float)
df_2[10] = df_2[10].astype(float)
#df_2.insert(0, "idx", range(0,len(df_2)), allow_duplicates=True)


df_3 = pd.read_csv("swag_new/swag_tag_shared_step_lr_5e-3_123.txt", header=None, sep='\s+', names=column_names)
df_3 = df_3[7:6500]
df_3[2] = df_3[2].astype(int)
df_3[4] = df_3[4].astype(float)
df_3[6] = df_3[6].astype(float)
df_3[8] = df_3[8].astype(float)
df_3[10] = df_3[10].astype(float)
#df_3.insert(0, "idx", range(0,len(df_3)), allow_duplicates=True)

df_4 = pd.read_csv("swag_new/swag_tag_shared_step_lr_5e-3_654.txt", header=None, sep='\s+', names=column_names)
df_4 = df_4[7:6500]
df_4[2] = df_4[2].astype(int)
df_4[4] = df_4[4].astype(float)
df_4[6] = df_4[6].astype(float)
df_4[8] = df_4[8].astype(float)
df_4[10] = df_4[10].astype(float)
#df_2.insert(0, "idx", range(0,len(df_2)), allow_duplicates=True)


df_5 = pd.read_csv("swag_new/swag_tag_shared_step_lr_5e-3_777.txt", header=None, sep='\s+', names=column_names)
df_5 = df_5[7:6500]
df_5[2] = df_5[2].astype(int)
df_5[4] = df_5[4].astype(float)
df_5[6] = df_5[6].astype(float)
df_5[8] = df_5[8].astype(float)
df_5[10] = df_5[10].astype(float)
#df_3.insert(0, "idx", range(0,len(df_3)), allow_duplicates=True)

# %%
sns.set()
df1 = pd.Series(df_1[6].astype(float))
df2 = pd.Series(df_2[6].astype(float))
df3 = pd.Series(df_3[6].astype(float))
df4 = pd.Series(df_4[6].astype(float))
df5 = pd.Series(df_5[6].astype(float))
mean_out = np.mean([df1,df2, df3, df4, df5], axis = 0)
std_out = np.std([df1, df2, df3, df4, df5], axis=0)

plt.show()
plt.plot(range(len(df1)), mean_out, 'b-', label='reward')
plt.fill_between(range(len(df1)), mean_out - std_out, mean_out + std_out, color='b', alpha=0.2)
plt.legend('r')
print(np.mean(mean_out[-30:]))

sns.set()
df1 = pd.Series(df_1[8].astype(float))
df2 = pd.Series(df_2[8].astype(float))
df3 = pd.Series(df_3[8].astype(float))
df4 = pd.Series(df_4[8].astype(float))
df5 = pd.Series(df_5[8].astype(float))
mean_out = np.mean([df1,df2, df3, df4, df5], axis = 0)
std_out = np.std([df1, df2, df3, df4, df5], axis=0)

plt.show()
plt.plot(range(len(df1)), mean_out, 'b-', label='closs')
plt.fill_between(range(len(df1)), mean_out - std_out, mean_out + std_out, color='b', alpha=0.2)
plt.legend()
print(np.mean(mean_out[-30:]))

sns.set()
df1 = pd.Series(df_1[10].astype(float))
df2 = pd.Series(df_2[10].astype(float))
df3 = pd.Series(df_3[10].astype(float))
df4 = pd.Series(df_4[10].astype(float))
df5 = pd.Series(df_5[10].astype(float))
mean_out = np.mean([df1,df2, df3, df4, df5], axis = 0)
std_out = np.std([df1, df2, df3, df4, df5], axis=0)

plt.show()
plt.plot(range(len(df1)), mean_out, 'b-', label='aloss')
plt.fill_between(range(len(df1)), mean_out - std_out, mean_out + std_out, color='b', alpha=0.2)
plt.legend()
print(np.mean(mean_out[-30:]))
# Out:
# 9.8
# 1.1491766666666665
# 3.862822

# %% [markdown]
# ## 5

# %%
with open("swag_new/maddpg_spread_1.txt", 'r') as temp_f:
    # get No of columns in each line
    col_count = [ len(l.split(" ")) for l in temp_f.readlines() ]
### Generate column names  (names will be 0, 1, 2, ..., maximum columns - 1)
column_names = [i for i in range(0, max(col_count)+1)]

df_1 = pd.read_csv("swag_new/maddpg_spread_1.txt", header=None, sep='\s+', names=column_names)
df_1 = df_1[10:]
df_1[2] = df_1[2].astype(int)
df_1[4] = df_1[4].astype(float)
df_1[6] = df_1[6].astype(float)
df_1[8] = df_1[8].astype(float)
df_1[10] = df_1[10].astype(float)
df_1.insert(0, "idx", range(0,len(df_1)), allow_duplicates=True)


df_2 = pd.read_csv("swag_new/maddpg_spread_123.txt", header=None, sep='\s+', names=column_names)
df_2 = df_2[10:]
df_2[2] = df_2[2].astype(int)
df_2[4] = df_2[4].astype(float)
df_2[6] = df_2[6].astype(float)
df_2[8] = df_2[8].astype(float)
df_2[10] = df_2[10].astype(float)
df_2.insert(0, "idx", range(0,len(df_2)), allow_duplicates=True)


df_3 = pd.read_csv("swag_new/maddpg_spread_777.txt", header=None, sep='\s+', names=column_names)
df_3 = df_3[10:]
df_3[2] = df_3[2].astype(int)
df_3[4] = df_3[4].astype(float)
df_3[6] = df_3[6].astype(float)
df_3[8] = df_3[8].astype(float)
df_3[10] = df_3[10].astype(float)
df_3.insert(0, "idx", range(0,len(df_3)), allow_duplicates=True)

# %%
sns.set()
df1 = pd.Series(df_1[4].astype(float))
df2 = pd.Series(df_2[4].astype(float))
df3 = pd.Series(df_3[4].astype(float))

mean_out = np.mean([df1,df2, df3], axis = 0)
std_out = np.std([df1, df2, df3], axis=0)

plt.show()
plt.plot(range(len(df1)), mean_out, 'b-', label='reward')
plt.fill_between(range(len(df1)), mean_out - std_out, mean_out + std_out, color='b', alpha=0.2)
plt.legend('r')
print(np.mean(mean_out[-30:]))

sns.set()
df1 = pd.Series(df_1[8].astype(float))
df2 = pd.Series(df_2[8].astype(float))
df3 = pd.Series(df_3[8].astype(float))

mean_out = np.mean([df1,df2, df3], axis = 0)
std_out = np.std([df1, df2, df3], axis=0)

plt.show()
plt.plot(range(len(df1)), mean_out, 'b-', label='reward')
plt.fill_between(range(len(df1)), mean_out - std_out, mean_out + std_out, color='b', alpha=0.2)
plt.legend('c')
print(np.mean(mean_out[-30:]))

sns.set()
df1 = pd.Series(df_1[10].astype(float))
df2 = pd.Series(df_2[10].astype(float))
df3 = pd.Series(df_3[10].astype(float))

mean_out = np.mean([df1,df2, df3], axis = 0)
std_out = np.std([df1, df2, df3], axis=0)

plt.show()

plt.plot(range(len(df1)), mean_out, 'b-', label='reward')
plt.fill_between(range(len(df1)), mean_out - std_out, mean_out + std_out, color='b', alpha=0.2)
plt.legend('a')
print(np.mean(mean_out[-30:]))
# Out:
# -150.77984888888886
# 0.7799955555555556
# 10.881757777777779

# %%
import pandas as pd
import seaborn as sns
import numpy as np
with open("swag_new/swag_spread_shared_lr1e-3_1.txt", 'r') as temp_f:
    # get No of columns in each line
    col_count = [ len(l.split(" ")) for l in temp_f.readlines() ]
### Generate column names  (names will be 0, 1, 2, ..., maximum columns - 1)
column_names = [i for i in range(0, max(col_count)+1)]

df_1 = pd.read_csv("swag_new/swag_spread_shared_lr1e-3_1.txt", header=None, sep='\s+', names=column_names)
df_1 = df_1[7:15000]
df_1[2] = df_1[2].astype(int)
df_1[4] = df_1[4].astype(float)
df_1[6] = df_1[6].astype(float)
df_1[8] = df_1[8].astype(float)
df_1[10] = df_1[10].astype(float)
#df_1.insert(0, "idx", range(0,len(df_1)), allow_duplicates=True)


df_2 = pd.read_csv("swag_new/swag_spread_shared_lr6e-4_1.txt", header=None, sep='\s+', names=column_names)
df_2 = df_2[7:15000]
df_2[2] = df_2[2].astype(int)
df_2[4] = df_2[4].astype(float)
df_2[6] = df_2[6].astype(float)
df_2[8] = df_2[8].astype(float)
df_2[10] = df_2[10].astype(float)
#df_2.insert(0, "idx", range(0,len(df_2)), allow_duplicates=True)


df_3 = pd.read_csv("swag_new/swag_spread_shared_lr8e-4_1.txt", header=None, sep='\s+', names=column_names)
df_3 = df_3[7:15000]
df_3[2] = df_3[2].astype(int)
df_3[4] = df_3[4].astype(float)
df_3[6] = df_3[6].astype(float)
df_3[8] = df_3[8].astype(float)
df_3[10] = df_3[10].astype(float)
#df_3.insert(0, "idx", range(0,len(df_3)), allow_duplicates=True)

df_4 = pd.read_csv("swag_new/swag_spread_shared_lr9e-4_1.txt", header=None, sep='\s+', names=column_names)
df_4 = df_4[7:15000]
df_4[2] = df_4[2].astype(int)
df_4[4] = df_4[4].astype(float)
df_4[6] = df_4[6].astype(float)
df_4[8] = df_4[8].astype(float)
df_4[10] = df_4[10].astype(float)
#df_2.insert(0, "idx", range(0,len(df_2)), allow_duplicates=True)


df_5 = pd.read_csv("swag_new/swag_spread_shared_lr11e-4_1.txt", header=None, sep='\s+', names=column_names)
df_5 = df_5[7:15000]
df_5[2] = df_5[2].astype(int)
df_5[4] = df_5[4].astype(float)
df_5[6] = df_5[6].astype(float)
df_5[8] = df_5[8].astype(float)
df_5[10] = df_5[10].astype(float)
#df_3.insert(0, "idx", range(0,len(df_3)), allow_duplicates=True)

# %%
sns.set()
df1 = pd.Series(df_1[4].astype(float))
df2 = pd.Series(df_2[4].astype(float))
df3 = pd.Series(df_3[4].astype(float))
df4 = pd.Series(df_4[4].astype(float))
df5 = pd.Series(df_5[4].astype(float))

print(np.mean(df1[-100:]),np.mean(df2[-100:]),np.mean(df3[-100:]),np.mean(df4[-100:]),np.mean(df5[-100:]))
plt.show()
plt.plot(range(len(df1)), df1, label='0.001')
plt.plot(range(len(df2)), df2, label='0.0006')
plt.plot(range(len(df3)), df3, label='0.0008')
plt.plot(range(len(df4)), df4, label='0.0009')
plt.plot(range(len(df5)), df5, label='0.0011')
plt.legend()

df1 = pd.Series(df_1[8].astype(float))
df2 = pd.Series(df_2[8].astype(float))
df3 = pd.Series(df_3[8].astype(float))
df4 = pd.Series(df_4[8].astype(float))
df5 = pd.Series(df_5[8].astype(float))

plt.show()
plt.plot(range(len(df1)), df1, label='0.001')
plt.plot(range(len(df2)), df2, label='0.0006')
plt.plot(range(len(df3)), df3, label='0.0008')
plt.plot(range(len(df4)), df4, label='0.0009')
plt.plot(range(len(df5)), df5, label='0.0011')
plt.legend()

df1 = pd.Series(df_1[10].astype(float))
df2 = pd.Series(df_2[10].astype(float))
df3 = pd.Series(df_3[10].astype(float))
df4 = pd.Series(df_4[10].astype(float))
df5 = pd.Series(df_5[10].astype(float))

plt.show()
plt.plot(range(len(df1)), df1, label='0.001')
plt.plot(range(len(df2)), df2, label='0.0006')
plt.plot(range(len(df3)), df3, label='0.0008')
plt.plot(range(len(df4)), df4, label='0.0009')
plt.plot(range(len(df5)), df5, label='0.0011')
plt.legend()
# Out:
# -169.63801100000003 -180.65171200000012 -178.86652899999999 -176.044763 -170.64458799999994

# %%
with open("swag_new/maddpg_spread_shared_lr11e-4_1.txt", 'r') as temp_f:
    # get No of columns in each line
    col_count = [ len(l.split(" ")) for l in temp_f.readlines() ]
### Generate column names  (names will be 0, 1, 2, ..., maximum columns - 1)
column_names = [i for i in range(0, max(col_count)+1)]

df_1 = pd.read_csv("swag_new/maddpg_spread_shared_lr11e-4_1.txt", header=None, sep='\s+', names=column_names)
df_1 = df_1[7:15000]
df_1[2] = df_1[2].astype(int)
df_1[4] = df_1[4].astype(float)
df_1[6] = df_1[6].astype(float)
df_1[8] = df_1[8].astype(float)
df_1[10] = df_1[10].astype(float)
#df_1.insert(0, "idx", range(0,len(df_1)), allow_duplicates=True)


df_2 = pd.read_csv("swag_new/swag_spread_shared_lr11e-4_1.txt", header=None, sep='\s+', names=column_names)
df_2 = df_2[7:15000]
df_2[2] = df_2[2].astype(int)
df_2[4] = df_2[4].astype(float)
df_2[6] = df_2[6].astype(float)
df_2[8] = df_2[8].astype(float)
df_2[10] = df_2[10].astype(float)
#df_2.insert(0, "idx", range(0,len(df_2)), allow_duplicates=True)

# %%
sns.set()
df1 = pd.Series(df_1[6].astype(float))
df2 = pd.Series(df_2[6].astype(float))

print(np.mean(df1[-50:]),np.mean(df2[-50:]))
plt.show()
plt.plot(range(len(df1)), df1, label='seed1')
plt.plot(range(len(df2)), df2, label='seed123')

plt.legend()

df1 = pd.Series(df_1[8].astype(float))
df2 = pd.Series(df_2[8].astype(float))

plt.show()
plt.plot(range(len(df1)), df1, label='seed1')
plt.plot(range(len(df2)), df2, label='seed123')

plt.legend()

df1 = pd.Series(df_1[10].astype(float))
df2 = pd.Series(df_2[10].astype(float))

plt.show()
plt.plot(range(len(df1)), df1, label='seed1')
plt.plot(range(len(df2)), df2, label='seed123')
plt.legend()
# Out:
# -154.444854 -176.80440599999994
